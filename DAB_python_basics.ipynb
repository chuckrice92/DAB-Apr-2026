# %%
integer = 3

# %%
print(integer)

# %%
type(integer)

# %%
float = 5.3

# %%
print(float)

# %%
type(float)

# %%
string = "charles"

# %%
print("charles")

# %%
type("charles")

# %%
boolean = True

# %%
10 > 5

# %%
print(boolean)

# %%
type(boolean)
